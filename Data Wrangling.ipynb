# %%
import csv

# %%
my_reader = csv.DictReader(open('data/eu_revolving_loans.csv', 'r'))
for row in my_reader:
    print(row)
# Out:
# OrderedDict([('Data Source in SDW: null', ''), (None, ['MIR.M.AT.B.A2Z.A.R.A.2250.EUR.N', 'MIR.M.BE.B.A2Z.A.R.A.2250.EUR.N', 'MIR.M.CY.B.A2Z.A.R.A.2250.EUR.N', 'MIR.M.DE.B.A2Z.A.R.A.2250.EUR.N', 'MIR.M.EE.B.A2Z.A.R.A.2250.EUR.N', 'MIR.M.ES.B.A2Z.A.R.A.2250.EUR.N', 'MIR.M.FI.B.A2Z.A.R.A.2250.EUR.N', 'MIR.M.FR.B.A2Z.A.R.A.2250.EUR.N', 'MIR.M.GR.B.A2Z.A.R.A.2250.EUR.N', 'MIR.M.IE.B.A2Z.A.R.A.2250.EUR.N', 'MIR.M.IT.B.A2Z.A.R.A.2250.EUR.N', 'MIR.M.LT.B.A2Z.A.R.A.2250.EUR.N', 'MIR.M.LU.B.A2Z.A.R.A.2250.EUR.N', 'MIR.M.LV.B.A2Z.A.R.A.2250.EUR.N', 'MIR.M.MT.B.A2Z.A.R.A.2250.EUR.N', 'MIR.M.NL.B.A2Z.A.R.A.2250.EUR.N', 'MIR.M.PT.B.A2Z.A.R.A.2250.EUR.N', 'MIR.M.SI.B.A2Z.A.R.A.2250.EUR.N', 'MIR.M.SK.B.A2Z.A.R.A.2250.EUR.N', 'MIR.M.U2.B.A2Z.A.R.A.2250.EUR.N'])])
# ...

# %% [markdown]
# ##### Remember DictReader is generator so it will only have one chance to go through the generator and get our data.
# If we need to iterate the file more than once, we should parse it into the other objectm like a list.

# %%
for row in my_reader:
    print(row)

# %%
## See no output after executing above code.

# %%
import pandas as pd

# %%
df = pd.read_csv('data/eu_revolving_loans.csv', header=[1,2,4] , index_col=0)

# %%
df.head()
# Out:
#              MIR.M.AT.B.A2Z.A.R.A.2250.EUR.N MIR.M.BE.B.A2Z.A.R.A.2250.EUR.N  \
#                                      Austria                         Belgium
# Period\Unit:            [Percent per annum ]            [Percent per annum ]
# 2016Feb                                 4.20                            8.09
# 2016Jan                                 4.17                            8.05
# 2015Dec                                 3.99                            8.21
# 2015Nov                                 4.09                            8.20
# 2015Oct                                 4.10                            8.40
#
#              MIR.M.CY.B.A2Z.A.R.A.2250.EUR.N MIR.M.DE.B.A2Z.A.R.A.2250.EUR.N  \
#                                       Cyprus                         Germany
# Period\Unit:            [Percent per annum ]            [Percent per annum ]
# 2016Feb                                 6.13                            8.85
# ...

# %% [markdown]
# ## Excel Files

# %%
import openpyxl # best library to load data from excel files

# %%
from openpyxl import load_workbook

# %%
wb = load_workbook(filename='data/climate_change_download_0.xlsx')

# %%
wb.get_sheet_names()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated function get_sheet_names (Use wb.sheetnames).
#   """Entry point for launching an IPython kernel.
# ['Data', 'Country', 'Series']

# %%
 ws = wb.get_sheet_by_name('Data')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated function get_sheet_by_name (Use wb[sheetname]).
#   """Entry point for launching an IPython kernel.

# %%
ws
# Out:
# <Worksheet "Data">

# %%
# for row in ws.rows:
#     for cell in row:
#         print(cell.value)

# %%
# !open data/GHE_DALY_Global_2000_2012.xls

# %%
df = pd.read_excel('data/GHE_DALY_Global_2000_2012.xls', sheetname='Global2012', header=[4,5])

# %%
df.head()
# Out:
#                         Unnamed: 0_level_0  \
#                         Unnamed: 0_level_1
# Population (thousands)                 NaN
# Live births (thousands)                NaN
# GHE code                               NaN
# 0                                      NaN
# 1                                       I.
#
#                                                         Unnamed: 1_level_0  \
#                                                         Unnamed: 1_level_1
# Population (thousands)                                                 NaN
# Live births (thousands)                                                NaN
# GHE code                                                GHE cause category
# 0                                                               All Causes
# 1                        Communicable, maternal, perinatal and nutritio...
#
#                         Unnamed: 2_level_0 Unnamed: 3_level_0       Sex  \
# ...

# %%
df.to_excel('data/my_new_excel.xlsx')

# %%
# !open data/my_new_excel.xlsx

# %% [markdown]
# ## PDFs
